# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score , confusion_matrix
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 40            5.0          3.5           1.3          0.3      setosa
# 102           7.1          3.0           5.9          2.1   virginica
# 82            5.8          2.7           3.9          1.2  versicolor
# 29            4.7          3.2           1.6          0.2      setosa
# 41            4.5          2.3           1.3          0.3      setosa

# %%
encoder = LabelEncoder()
df['species'] = encoder.fit_transform(df['species'])
df.sample(5)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 143           6.8          3.2           5.9          2.3        2
# 62            6.0          2.2           4.0          1.0        1
# 20            5.4          3.4           1.7          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 123           6.3          2.7           4.9          1.8        2

# %%
df = df[['sepal_length','petal_length','species']]
df.sample(5)
# Out:
#      sepal_length  petal_length  species
# 104           6.5           5.8        2
# 73            6.1           4.7        1
# 33            5.5           1.4        0
# 116           6.5           5.5        2
# 145           6.7           5.2        2

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
clf = LogisticRegression()
# Automatically realises that it is a multi class problem

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9666666666666667

# %%
pd.DataFrame(confusion_matrix(y_test,y_pred))
# Out:
#     0  1  2
# 0  14  0  0
# 1   0  7  1
# 2   0  0  8

# %%
# Prediction
query = np.array([[3.4,2.7]])
clf.predict_proba(query)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([[7.25865651e-01, 2.73720718e-01, 4.13631316e-04]])

# %% [markdown]
# Setosa = 7.25e-01 , versicolor = 2.73e-01 , virginica = 4.13 e-04

# %%
clf.predict(query)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from mlxtend.plotting import plot_decision_regions

plot_decision_regions(X.values , y.values , clf , legend=2)

# Adding axes annotations

plt.xlabel('Sepal Length (cm)')
plt.ylabel('Petal Length (cm)')
plt.title('Softmax on Iris')

plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
